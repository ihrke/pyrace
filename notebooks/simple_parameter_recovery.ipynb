# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# WARNING: you have a design with more than 2 responses
#   though the code can handle this situation in principle, I've never tested it
#   and there seem to be issues. That said, have fun!
# <Design>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.79,A=1.08,B=0.86,V=-4.34,v=-0.37)
# Testmod(Testparspec(ter=0.79,A=1.08,B=0.86,V=-4.34,v=-0.37))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#          RT  SSD  correct  response     fac1     fac2     fac3
# 0  4.077629  NaN        0         1  level11  level21  level31
# 1  5.789547  NaN        0         2  level11  level21  level31
# 2  7.458771  NaN        0         2  level11  level21  level31
# 3  4.858809  NaN        0         1  level11  level21  level31
# 4  4.661294  NaN        0         1  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 200, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=25390.28, median=14534.06, range=(12309.40, 80286.10)
# DE(10): mean=12717.17, median=12406.20, range=(12308.72, 14788.36)
# DE(20): mean=12510.62, median=12363.10, range=(12305.92, 13769.33)
# DE(30): mean=12368.73, median=12331.48, range=(12305.92, 12809.81)
# DE(40): mean=12342.40, median=12326.63, range=(12305.44, 12563.29)
# DE(50): mean=12338.32, median=12321.56, range=(12305.44, 12563.29)
# DE(60): mean=12334.94, median=12315.63, range=(12303.64, 12563.29)
# DE(70): mean=12328.87, median=12313.44, range=(12303.64, 12562.55)
# DE(80): mean=12327.86, median=12313.44, range=(12303.64, 12558.77)
# DE(90): mean=12325.10, median=12312.58, range=(12303.64, 12514.09)
# DE(100): mean=12319.60, median=12312.48, range=(12303.04, 12396.79)
# DE(110): mean=12316.95, median=12312.08, range=(12303.04, 12384.90)
# DE(120): mean=12316.05, median=12312.08, range=(12303.04, 12368.13)
# DE(130): mean=12313.45, median=12311.68, range=(12303.04, 12359.59)
# DE(140): mean=12312.69, median=12310.33, range=(12303.04, 12359.59)
# DE(150): mean=12312.58, median=12310.15, range=(12303.04, 12359.59)
# DE(160): mean=12312.29, median=12309.72, range=(12303.04, 12359.59)
# DE(170): mean=12312.02, median=12309.72, range=(12302.96, 12359.59)
# DE(180): mean=12311.80, median=12309.72, range=(12302.96, 12359.59)
# DE(190): mean=12311.38, median=12308.24, range=(12302.96, 12359.59)
# DE(200) reached gen_max=200
# > Optimization run 1: Bestscore:  12302.9554116
# > Optimization run 1: Best:  Testparspec(ter=0.94,A=1.24,B=0.64,V=-4.71,v=5.00)
# (Testparspec(ter=0.94,A=1.24,B=0.64,V=-4.71,v=5.00), 12302.955411560384)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'xtol': 0.1, 'full_output': True, 'ftol': 1.0}
# Optimization terminated successfully.
#          Current function value: 12302.773162
#          Iterations: 38
#          Function evaluations: 71
# > Optimization run 1: Bestscore:  12302.7731624
# > Optimization run 1: Best:  Testparspec(ter=0.93,A=1.25,B=0.63,V=-4.77,v=5.00)
# Optimization terminated successfully.
#          Current function value: 12302.762136
#          Iterations: 226
#          Function evaluations: 401
# > Optimization run 2: Bestscore:  12302.7621362
# > Optimization run 2: Best:  Testparspec(ter=0.94,A=1.21,B=0.61,V=-4.97,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 12302.760945
#          Iterations: 101
#          Function evaluations: 196
# > Optimization run 3: Bestscore:  12302.7609452
# > Optimization run 3: Best:  Testparspec(ter=0.93,A=1.20,B=0.61,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 12302.760904
#          Iterations: 45
#          Function evaluations: 111
# > Optimization run 4: Bestscore:  12302.7609038
# > Optimization run 4: Best:  Testparspec(ter=0.93,A=1.20,B=0.61,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 12302.760885
#          Iterations: 51
#          Function evaluations: 117
# > Optimization run 5: Bestscore:  12302.7608848
# > Optimization run 5: Best:  Testparspec(ter=0.93,A=1.20,B=0.61,V=-4.99,v=-5.00)
# (Testparspec(ter=0.93,A=1.20,B=0.61,V=-4.99,v=-5.00), 12302.760884770265)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# Testparspec(ter=0.94,A=1.24,B=0.64,V=-4.71,v=5.00)
# Testparspec(ter=0.93,A=1.20,B=0.61,V=-4.99,v=-5.00)
