# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# <Design>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.19,A=1.52,B=0.26,V=-2.30,v=-4.81)
# Testmod(Testparspec(ter=0.19,A=1.52,B=0.26,V=-2.30,v=-4.81))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#          RT  SSD  correct  response     fac1     fac2     fac3
# 0  3.195202  NaN        1         0  level11  level21  level31
# 1  1.969429  NaN        1         0  level11  level21  level31
# 2  0.696571  NaN        0         2  level11  level21  level31
# 3  2.253537  NaN        0         2  level11  level21  level31
# 4  5.761364  NaN        0         2  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-301db116dbdb> in <module>()
# ----> 1 opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200, ncpu=6)
#       2 opt.optimize()
#
# /home/travis/virtualenv/python2.7/local/lib/python2.7/site-packages/pyrace-0.1.0-py2.7-linux-x86_64.egg/pyrace/optimize/diffev.pyc in __init__(self, model, data, optfunc, optfunc_pars, save_stats, xtol, ftol, nxtol, pop_ini, pop_size, F, CR, trace_stats, gen_max, **kwargs)
#     240         gen_max : maximum number of generations (only when no convergence)
#     241         """
# --> 242         self.set_general_opts(**kwargs)
#     243         self.opttype=self.__class__.__name__
#     244
#
# /home/travis/virtualenv/python2.7/local/lib/python2.7/site-packages/pyrace-0.1.0-py2.7-linux-x86_64.egg/pyrace/optimize/objective.pyc in set_general_opts(self, noptimizations, trace, pool, ncpu, **kwargs)
#      49         else:
#      50             if ncpu!=None and ncpu>1:
# ---> 51                 self.pool=mp.Pool(ncpu)
#      52                 self.ncpu=ncpu
#      53             else:
#
# /usr/lib/python2.7/multiprocessing/__init__.pyc in Pool(processes, initializer, initargs, maxtasksperchild)
#     230     '''
#     231     from multiprocessing.pool import Pool
# --> 232     return Pool(processes, initializer, initargs, maxtasksperchild)
#     233
#     234 def RawValue(typecode_or_type, *args):
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in __init__(self, processes, initializer, initargs, maxtasksperchild)
#     113     def __init__(self, processes=None, initializer=None, initargs=(),
#     114                  maxtasksperchild=None):
# --> 115         self._setup_queues()
#     116         self._taskqueue = Queue.Queue()
#     117         self._cache = {}
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in _setup_queues(self)
#     208     def _setup_queues(self):
#     209         from .queues import SimpleQueue
# --> 210         self._inqueue = SimpleQueue()
#     211         self._outqueue = SimpleQueue()
#     212         self._quick_put = self._inqueue._writer.send
#
# /usr/lib/python2.7/multiprocessing/queues.pyc in __init__(self)
#     350     def __init__(self):
#     351         self._reader, self._writer = Pipe(duplex=False)
# --> 352         self._rlock = Lock()
#     353         if sys.platform == 'win32':
#     354             self._wlock = None
#
# /usr/lib/python2.7/multiprocessing/synchronize.pyc in __init__(self)
#     145
#     146     def __init__(self):
# --> 147         SemLock.__init__(self, SEMAPHORE, 1, 1)
#     148
#     149     def __repr__(self):
#
# /usr/lib/python2.7/multiprocessing/synchronize.pyc in __init__(self, kind, value, maxvalue)
#      73
#      74     def __init__(self, kind, value, maxvalue):
# ---> 75         sl = self._semlock = _multiprocessing.SemLock(kind, value, maxvalue)
#      76         debug('created semlock with handle %s' % sl.handle)
#      77         self._make_methods()
#
# OSError: [Errno 13] Permission denied

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-12c8f99b21c8> in <module>()
# ----> 1 opt.plot_stats()
#
# NameError: name 'opt' is not defined

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cba6fd32b3f5> in <module>()
#       1 simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
# ----> 2 simplex.set_startpoint(opt.get_best())
#       3 simplex.optimize()
#
# NameError: name 'opt' is not defined

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5d9dae92c03d> in <module>()
# ----> 1 pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])
#
# NameError: name 'opt' is not defined

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-78fd0f14cd30> in <module>()
#       1 # and look at the best individual
# ----> 2 bestde=opt.get_best()
#       3 bestsimp=simplex.get_best()
#       4 display(best)
#       5 display(bestsimp)
#
# NameError: name 'opt' is not defined
