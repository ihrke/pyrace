# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# WARNING: you have a design with more than 2 responses
#   though the code can handle this situation in principle, I've never tested it
#   and there seem to be issues. That said, have fun!
# <Design 'unknown'>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.46,A=1.37,B=4.58,V=0.33,v=-3.05)
# Testmod(Testparspec(ter=0.46,A=1.37,B=4.58,V=0.33,v=-3.05))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#          RT  SSD  correct  response     fac1     fac2     fac3
# 0  4.308686  NaN        0         1  level11  level21  level31
# 1  4.362951  NaN        0         1  level11  level21  level31
# 2  5.301482  NaN        1         0  level11  level21  level31
# 3  3.122482  NaN        0         2  level11  level21  level31
# 4  5.390657  NaN        0         2  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 200, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=28015.64, median=17058.44, range=(10793.32, 79027.44)
# DE(10): mean=13294.55, median=11349.05, range=(10609.92, 25056.25)
# DE(20): mean=11594.29, median=10984.70, range=(10591.21, 17154.56)
# DE(30): mean=10941.56, median=10835.31, range=(10570.37, 12681.51)
# DE(40): mean=10770.76, median=10690.25, range=(10570.37, 11116.33)
# DE(50): mean=10719.92, median=10630.62, range=(10568.35, 11019.93)
# DE(60): mean=10699.24, median=10630.62, range=(10568.35, 11019.93)
# DE(70): mean=10682.24, median=10618.59, range=(10566.20, 10973.93)
# DE(80): mean=10663.28, median=10616.22, range=(10566.20, 10973.93)
# DE(90): mean=10661.61, median=10616.22, range=(10566.20, 10973.93)
# DE(100): mean=10654.97, median=10616.22, range=(10566.20, 10973.51)
# DE(110): mean=10654.38, median=10616.22, range=(10566.20, 10973.51)
# DE(120): mean=10643.95, median=10592.53, range=(10566.20, 10973.51)
# DE(130): mean=10642.48, median=10591.48, range=(10564.63, 10973.51)
# DE(140): mean=10640.80, median=10591.39, range=(10564.63, 10973.12)
# DE(150): mean=10639.79, median=10591.39, range=(10564.42, 10969.98)
# DE(160): mean=10635.83, median=10591.39, range=(10564.42, 10969.98)
# DE(170): mean=10634.42, median=10591.39, range=(10563.43, 10969.98)
# DE(180): mean=10631.18, median=10591.39, range=(10563.43, 10938.55)
# DE(190): mean=10630.47, median=10591.39, range=(10563.43, 10938.55)
# DE(200) reached gen_max=200
# > Optimization run 1: Bestscore:  10563.4314964
# > Optimization run 1: Best:  Testparspec(ter=1.00,A=3.17,B=2.37,V=-0.07,v=-5.00)
# (Testparspec(ter=1.00,A=3.17,B=2.37,V=-0.07,v=-5.00), 10563.431496383888)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'disp': 1, 'xtol': 0.1, 'full_output': True, 'ftol': 1.0} (5 times)
# Optimization terminated successfully.
#          Current function value: 10560.236444
#          Iterations: 132
#          Function evaluations: 241
# > Optimization run 1: Bestscore:  10560.2364439
# > Optimization run 1: Best:  Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 10560.236444
#          Iterations: 73
#          Function evaluations: 139
# > Optimization run 2: Bestscore:  10560.2364437
# > Optimization run 2: Best:  Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 10560.236444
#          Iterations: 66
#          Function evaluations: 140
# > Optimization run 3: Bestscore:  10560.2364437
# > Optimization run 3: Best:  Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 10560.236444
#          Iterations: 58
#          Function evaluations: 140
# > Optimization run 4: Bestscore:  10560.2364437
# > Optimization run 4: Best:  Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 10560.236444
#          Iterations: 58
#          Function evaluations: 140
# > Optimization run 5: Bestscore:  10560.2364437
# > Optimization run 5: Best:  Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
# (Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00), 10560.236443703781)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# Testparspec(ter=1.00,A=3.17,B=2.37,V=-0.07,v=-5.00)
# Testparspec(ter=1.00,A=3.54,B=2.57,V=0.16,v=-5.00)
