# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# <Design>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.05,A=0.57,B=0.16,V=-4.11,v=3.64)
# Testmod(Testparspec(ter=0.05,A=0.57,B=0.16,V=-4.11,v=3.64))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#          RT  SSD  correct  response     fac1     fac2     fac3
# 0  0.737823  NaN        0         2  level11  level21  level31
# 1  0.811903  NaN        0         1  level11  level21  level31
# 2  0.305432  NaN        1         0  level11  level21  level31
# 3  0.932964  NaN        0         1  level11  level21  level31
# 4  1.576488  NaN        0         1  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel)

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200, ncpu=6)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 100, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=37611.10, median=38867.89, range=(11227.25, 69697.92)
# DE(10): mean=12695.14, median=10345.64, range=(8289.45, 41602.09)
# DE(20): mean=9862.43, median=8708.98, range=(8287.92, 14874.44)
# DE(30): mean=9374.96, median=8627.86, range=(8287.92, 13305.09)
# DE(40): mean=9147.30, median=8545.75, range=(8287.54, 13082.23)
# DE(50): mean=8990.77, median=8461.40, range=(8287.53, 13082.23)
# DE(60): mean=8749.57, median=8415.31, range=(8287.53, 11801.27)
# DE(70): mean=8665.59, median=8367.71, range=(8287.53, 11405.03)
# DE(80): mean=8639.44, median=8367.46, range=(8287.53, 11133.61)
# DE(90): mean=8576.41, median=8367.46, range=(8287.53, 11132.82)
# DE(100) reached gen_max=100
# > Optimization run 1: Bestscore:  8287.52789569
# > Optimization run 1: Best:  Testparspec(ter=0.00,A=0.74,B=0.30,V=-2.41,v=5.00)
# (Testparspec(ter=0.00,A=0.74,B=0.30,V=-2.41,v=5.00), 8287.527895692494)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'xtol': 0.1, 'full_output': True, 'ftol': 1.0}
# Optimization terminated successfully.
#          Current function value: 8284.622544
#          Iterations: 225
#          Function evaluations: 378
# > Optimization run 1: Bestscore:  8284.62254372
# > Optimization run 1: Best:  Testparspec(ter=0.06,A=0.63,B=0.16,V=-3.69,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 8284.529007
#          Iterations: 516
#          Function evaluations: 852
# > Optimization run 2: Bestscore:  8284.52900746
# > Optimization run 2: Best:  Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.94,v=5.00)
# Optimization terminated successfully.
#          Current function value: 8284.527769
#          Iterations: 146
#          Function evaluations: 287
# > Optimization run 3: Bestscore:  8284.52776923
# > Optimization run 3: Best:  Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.98,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 8284.527101
#          Iterations: 61
#          Function evaluations: 129
# > Optimization run 4: Bestscore:  8284.52710122
# > Optimization run 4: Best:  Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.98,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 8284.526748
#          Iterations: 78
#          Function evaluations: 162
# > Optimization run 5: Bestscore:  8284.52674845
# > Optimization run 5: Best:  Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.99,v=-5.00)
# (Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.99,v=-5.00), 8284.5267484510168)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(best)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# Testparspec(ter=0.00,A=0.74,B=0.30,V=-2.41,v=5.00)
# Testparspec(ter=0.06,A=0.48,B=0.13,V=-4.99,v=-5.00)
