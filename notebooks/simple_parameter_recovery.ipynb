# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# <Design>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.19,A=0.48,B=2.48,V=2.42,v=1.48)
# Testmod(Testparspec(ter=0.19,A=0.48,B=2.48,V=2.42,v=1.48))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#          RT  SSD  correct  response     fac1     fac2     fac3
# 0  1.556117  NaN        1         0  level11  level21  level31
# 1  1.167597  NaN        1         0  level11  level21  level31
# 2  1.112329  NaN        0         1  level11  level21  level31
# 3  1.025599  NaN        1         0  level11  level21  level31
# 4  1.187060  NaN        0         1  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 200, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=45796.82, median=51754.80, range=(4022.82, 81161.26)
# DE(10): mean=9464.08, median=4338.60, range=(3421.29, 74019.78)
# DE(20): mean=5079.85, median=4034.69, range=(3374.25, 19326.79)
# DE(30): mean=4312.67, median=3945.65, range=(3356.71, 6984.19)
# DE(40): mean=4170.79, median=3862.33, range=(3356.71, 6984.19)
# DE(50): mean=3971.51, median=3668.86, range=(3355.82, 6682.68)
# DE(60): mean=3902.39, median=3668.86, range=(3355.82, 6161.90)
# DE(70): mean=3880.28, median=3654.44, range=(3355.82, 6033.49)
# DE(80): mean=3806.47, median=3626.48, range=(3355.82, 5127.27)
# DE(90): mean=3729.94, median=3577.10, range=(3355.82, 4903.76)
# DE(100): mean=3706.27, median=3577.10, range=(3355.82, 4657.23)
# DE(110): mean=3671.49, median=3577.10, range=(3355.34, 4396.83)
# DE(120): mean=3634.85, median=3577.10, range=(3355.34, 4336.66)
# DE(130): mean=3626.93, median=3526.38, range=(3355.34, 4336.66)
# DE(140): mean=3616.99, median=3496.71, range=(3355.34, 4336.64)
# DE(150): mean=3610.83, median=3496.71, range=(3355.34, 4336.64)
# DE(160): mean=3603.49, median=3496.71, range=(3355.34, 4336.64)
# DE(170): mean=3594.09, median=3494.71, range=(3355.34, 4336.64)
# DE(180): mean=3575.73, median=3494.71, range=(3355.34, 4098.70)
# DE(190): mean=3570.02, median=3494.71, range=(3355.34, 4098.70)
# DE(200) reached gen_max=200
# > Optimization run 1: Bestscore:  3355.33794009
# > Optimization run 1: Best:  Testparspec(ter=0.05,A=0.06,B=3.65,V=2.96,v=5.00)
# (Testparspec(ter=0.05,A=0.06,B=3.65,V=2.96,v=5.00), 3355.3379400892172)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'xtol': 0.1, 'full_output': True, 'ftol': 1.0}
# Optimization terminated successfully.
#          Current function value: 3346.312305
#          Iterations: 169
#          Function evaluations: 293
# > Optimization run 1: Bestscore:  3346.31230514
# > Optimization run 1: Best:  Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00)
# Optimization terminated successfully.
#          Current function value: 3346.312267
#          Iterations: 59
#          Function evaluations: 138
# > Optimization run 2: Bestscore:  3346.31226747
# > Optimization run 2: Best:  Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00)
# Optimization terminated successfully.
#          Current function value: 3346.312177
#          Iterations: 51
#          Function evaluations: 127
# > Optimization run 3: Bestscore:  3346.31217672
# > Optimization run 3: Best:  Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00)
# Optimization terminated successfully.
#          Current function value: 3346.312154
#          Iterations: 55
#          Function evaluations: 134
# > Optimization run 4: Bestscore:  3346.31215434
# > Optimization run 4: Best:  Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00)
# Optimization terminated successfully.
#          Current function value: 3346.311858
#          Iterations: 46
#          Function evaluations: 118
# > Optimization run 5: Bestscore:  3346.31185828
# > Optimization run 5: Best:  Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00)
# (Testparspec(ter=0.18,A=0.00,B=2.74,V=2.42,v=5.00), 3346.3118582833772)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-78fd0f14cd30> in <module>()
#       2 bestde=opt.get_best()
#       3 bestsimp=simplex.get_best()
# ----> 4 display(best)
#       5 display(bestsimp)
#       6
#
# NameError: name 'best' is not defined
