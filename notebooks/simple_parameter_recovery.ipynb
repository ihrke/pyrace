# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# WARNING: you have a design with more than 2 responses
#   though the code can handle this situation in principle, I've never tested it
#   and there seem to be issues. That said, have fun!
# <Design>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.76,A=3.90,B=0.69,V=-2.80,v=-0.31)
# Testmod(Testparspec(ter=0.76,A=3.90,B=0.69,V=-2.80,v=-0.31))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#           RT  SSD  correct  response     fac1     fac2     fac3
# 0   2.022684  NaN        0         1  level11  level21  level31
# 1  18.933217  NaN        0         2  level11  level21  level31
# 2  24.079363  NaN        0         2  level11  level21  level31
# 3  38.854489  NaN        0         2  level11  level21  level31
# 4   7.477635  NaN        0         1  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 200, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=32917.92, median=19467.56, range=(13183.80, 78408.35)
# DE(10): mean=16553.03, median=13998.66, range=(13147.40, 44622.22)
# DE(20): mean=14316.79, median=13377.84, range=(13130.97, 21298.09)
# DE(30): mean=13570.13, median=13280.48, range=(13130.97, 17541.33)
# DE(40): mean=13300.94, median=13217.65, range=(13130.09, 13872.01)
# DE(50): mean=13261.35, median=13217.65, range=(13130.09, 13799.07)
# DE(60): mean=13251.16, median=13217.65, range=(13130.09, 13791.90)
# DE(70): mean=13234.85, median=13217.65, range=(13130.09, 13772.44)
# DE(80): mean=13230.30, median=13209.22, range=(13130.09, 13772.44)
# DE(90): mean=13214.07, median=13198.57, range=(13130.09, 13422.43)
# DE(100): mean=13212.63, median=13198.57, range=(13130.09, 13400.74)
# DE(110): mean=13211.80, median=13198.57, range=(13129.83, 13400.74)
# DE(120): mean=13211.00, median=13181.65, range=(13129.83, 13400.74)
# DE(130): mean=13205.24, median=13165.37, range=(13129.83, 13382.01)
# DE(140): mean=13202.67, median=13165.37, range=(13129.83, 13370.07)
# DE(150): mean=13202.04, median=13165.37, range=(13129.83, 13370.05)
# DE(160): mean=13200.63, median=13165.37, range=(13129.83, 13370.05)
# DE(170): mean=13200.01, median=13165.37, range=(13129.83, 13370.05)
# DE(180): mean=13189.03, median=13150.24, range=(13129.45, 13345.19)
# DE(190): mean=13187.75, median=13149.38, range=(13129.45, 13345.19)
# DE(200) reached gen_max=200
# > Optimization run 1: Bestscore:  13129.4509788
# > Optimization run 1: Best:  Testparspec(ter=0.08,A=0.81,B=1.58,V=-3.73,v=5.00)
# (Testparspec(ter=0.08,A=0.81,B=1.58,V=-3.73,v=5.00), 13129.450978761701)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'xtol': 0.1, 'full_output': True, 'ftol': 1.0}
# Optimization terminated successfully.
#          Current function value: 13128.363813
#          Iterations: 260
#          Function evaluations: 437
# > Optimization run 1: Bestscore:  13128.363813
# > Optimization run 1: Best:  Testparspec(ter=0.03,A=0.13,B=1.49,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 13128.363278
#          Iterations: 34
#          Function evaluations: 90
# > Optimization run 2: Bestscore:  13128.363278
# > Optimization run 2: Best:  Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 13128.363150
#          Iterations: 36
#          Function evaluations: 93
# > Optimization run 3: Bestscore:  13128.3631503
# > Optimization run 3: Best:  Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 13128.363097
#          Iterations: 33
#          Function evaluations: 91
# > Optimization run 4: Bestscore:  13128.3630965
# > Optimization run 4: Best:  Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00)
# Optimization terminated successfully.
#          Current function value: 13128.363097
#          Iterations: 32
#          Function evaluations: 94
# > Optimization run 5: Bestscore:  13128.3630965
# > Optimization run 5: Best:  Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00)
# (Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00), 13128.363096524148)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# Testparspec(ter=0.08,A=0.81,B=1.58,V=-3.73,v=5.00)
# Testparspec(ter=0.04,A=0.13,B=1.49,V=-4.99,v=-5.00)
