# %% [markdown]
# # Demonstrating recovering parameters from simulated data

# %%
import numpy as np
import pylab as pl
import pandas as pd
import multiprocessing as mp
import pyrace

# %% [markdown]
# ## First specify the design
#
# we need all factors and all responses (one of which must map to one of the features)

# %%
factors=[{'fac1':['level11','level12', 'level13']},
         {'fac2':['level21','level22', 'level23']},
         {'fac3':['level31','level32']}]
responses=['level21', 'level22', 'level23']
design=pyrace.Design(factors, responses, 'fac2')
print design
# Out:
# WARNING: you have a design with more than 2 responses
#   though the code can handle this situation in principle, I've never tested it
#   and there seem to be issues. That said, have fun!
# <Design 'unknown'>
#  fac2: ['level21', 'level22', 'level23']
#  fac3: ['level31', 'level32']
#  fac1: ['level11', 'level12', 'level13']
#  --------------------
#  condition 0 <-> ['level11', 'level21', 'level31']
#  condition 1 <-> ['level11', 'level21', 'level32']
#  condition 2 <-> ['level11', 'level22', 'level31']
#  condition 3 <-> ['level11', 'level22', 'level32']
#  condition 4 <-> ['level11', 'level23', 'level31']
#  condition 5 <-> ['level11', 'level23', 'level32']
#  condition 6 <-> ['level12', 'level21', 'level31']
#  condition 7 <-> ['level12', 'level21', 'level32']
#  condition 8 <-> ['level12', 'level22', 'level31']
#  condition 9 <-> ['level12', 'level22', 'level32']
#  condition 10 <-> ['level12', 'level23', 'level31']
#  condition 11 <-> ['level12', 'level23', 'level32']
#  condition 12 <-> ['level13', 'level21', 'level31']
#  condition 13 <-> ['level13', 'level21', 'level32']
#  condition 14 <-> ['level13', 'level22', 'level31']
#  condition 15 <-> ['level13', 'level22', 'level32']
#  condition 16 <-> ['level13', 'level23', 'level31']
#  condition 17 <-> ['level13', 'level23', 'level32']
#  response  0 <-> level21
#  response  1 <-> level22
#  response  2 <-> level23

# %% [markdown]
# ## Specifiy the model
#
# * we need to subclass `pyrace.Parameters` to define which parameters we have
# * we need to sublcass `pyrace.pSSLBA` (or another race-model) to define which parameter goes where

# %%
class Testparspec(pyrace.Parameters):
    parnames=['ter', 'A', 'B', 'V', 'v']
    lower=[0, 0, 0, -5, -5]
    upper=[1, 4, 5, 5, 5]
    
class Testmod(pyrace.pSSLBA):
    paramspec=Testparspec;
    def __init__(self,design):
        self.design=design
        self.sv=1.0
        self.set_mixing_probabilities(0,0)
        self.set_params(self.paramspec().random())
    def set_params(self,pars):
        self.params=pars
        go_acc=[]
        stop_acc=[]
        for cond in range(self.design.nconditions()):
            go_acc.append( [pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B)
                            for resp in self.design.get_responses()])
            stop_acc.append(pyrace.LBAAccumulator(pars.ter, pars.A, pars.V, self.sv, pars.A+pars.B))
        self.set_accumulators(go_acc, stop_acc)

# %%
# create a model-instance
mod=Testmod(design)

# this is a random parameter with which the data is going to be simulated
truepar=mod.params
display(truepar)

# print and plot the model (may look weird, because the parameters are random)
print mod
pl.figure(figsize=(20,20))
mod.plot_model(lims=(0.1,3))
# Out:
# Testparspec(ter=0.72,A=1.59,B=2.17,V=-4.01,v=-4.39)
# Testmod(Testparspec(ter=0.72,A=1.59,B=2.17,V=-4.01,v=-4.39))

# %% [markdown]
# ## Simulate data

# %%
dsim=mod.simulate(100) # 500 trials per condition
dsim.as_dataframe(form='wide').head()
# Out:
#           RT  SSD  correct  response     fac1     fac2     fac3
# 0   6.796589  NaN        1         0  level11  level21  level31
# 1  13.501821  NaN        0         1  level11  level21  level31
# 2   7.835398  NaN        0         2  level11  level21  level31
# 3  16.409241  NaN        1         0  level11  level21  level31
# 4   4.013828  NaN        0         1  level11  level21  level31

# %% [markdown]
# ## Optimize the parameters
#
# we use a Differential-Evolution Optimizer here
#
# * note that it can run on multiple cores (the population is evaluated in parallel) by giving ncpu=number

# %%
opt=pyrace.DEOptimizer(mod, dsim, save_stats=10, trace_stats=10, gen_max=200)
opt.optimize()
# Out:
# > Optimize with DEOptimizer and options {'trace_stats': 10, 'save_stats': 10, 'F': 0.5, 'gen_max': 200, 'progressbar': False, 'nxtol': 10, 'xtol': None, 'CR': 0, 'ftol': None}
# DE(0): mean=32578.59, median=21691.06, range=(14298.44, 76537.74)
# DE(10): mean=16070.31, median=14586.63, range=(14295.61, 28926.92)
# DE(20): mean=15101.86, median=14363.24, range=(14294.04, 27192.38)
# DE(30): mean=14573.63, median=14327.20, range=(14294.04, 18627.51)
# DE(40): mean=14400.47, median=14313.12, range=(14294.02, 15168.58)
# DE(50): mean=14391.37, median=14308.16, range=(14294.02, 15081.18)
# DE(60): mean=14369.02, median=14307.46, range=(14294.02, 14910.62)
# DE(70): mean=14359.78, median=14305.01, range=(14294.02, 14910.62)
# DE(80): mean=14357.62, median=14299.16, range=(14294.02, 14910.38)
# DE(90): mean=14347.59, median=14299.16, range=(14294.02, 14910.09)
# DE(100): mean=14342.96, median=14298.83, range=(14292.84, 14908.32)
# DE(110): mean=14341.67, median=14297.68, range=(14292.84, 14908.32)
# DE(120): mean=14327.95, median=14297.06, range=(14292.64, 14579.97)
# DE(130): mean=14327.83, median=14296.87, range=(14292.64, 14579.97)
# DE(140): mean=14324.73, median=14296.76, range=(14292.64, 14579.95)
# DE(150): mean=14318.45, median=14295.71, range=(14292.64, 14578.96)
# DE(160): mean=14318.27, median=14295.53, range=(14292.64, 14578.96)
# DE(170): mean=14317.90, median=14295.53, range=(14292.64, 14578.61)
# DE(180): mean=14317.84, median=14295.26, range=(14292.64, 14578.61)
# DE(190): mean=14317.79, median=14295.18, range=(14292.64, 14578.61)
# DE(200) reached gen_max=200
# > Optimization run 1: Bestscore:  14292.6396732
# > Optimization run 1: Best:  Testparspec(ter=0.57,A=0.23,B=3.37,V=-3.11,v=5.00)
# (Testparspec(ter=0.57,A=0.23,B=3.37,V=-3.11,v=5.00), 14292.639673150035)

# %% [markdown]
# we may plot the convergence

# %%
opt.plot_stats()

# %% [markdown]
# if we are not satisfied, we might want to run a simplex starting at the current optimum to see if we can get better with gradient descent

# %%
simplex=pyrace.SimplexOptimizer(mod, dsim, noptimizations=5, xtol=.1)
simplex.set_startpoint(opt.get_best())
simplex.optimize()
# Out:
# > Optimize with SimplexOptimizer and options {'disp': 1, 'xtol': 0.1, 'full_output': True, 'ftol': 1.0} (5 times)
# Optimization terminated successfully.
#          Current function value: 14292.559395
#          Iterations: 226
#          Function evaluations: 391
# > Optimization run 1: Bestscore:  14292.5593955
# > Optimization run 1: Best:  Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
# Optimization terminated successfully.
#          Current function value: 14292.558648
#          Iterations: 29
#          Function evaluations: 83
# > Optimization run 2: Bestscore:  14292.5586478
# > Optimization run 2: Best:  Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
# Optimization terminated successfully.
#          Current function value: 14292.558648
#          Iterations: 42
#          Function evaluations: 106
# > Optimization run 3: Bestscore:  14292.5586478
# > Optimization run 3: Best:  Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
# Optimization terminated successfully.
#          Current function value: 14292.558648
#          Iterations: 42
#          Function evaluations: 106
# > Optimization run 4: Bestscore:  14292.5586478
# > Optimization run 4: Best:  Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
# Optimization terminated successfully.
#          Current function value: 14292.558648
#          Iterations: 42
#          Function evaluations: 106
# > Optimization run 5: Bestscore:  14292.5586478
# > Optimization run 5: Best:  Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
# (Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00), 14292.558647758018)

# %% [markdown]
# ### how much better did we get?

# %%
simplex.plot_convergence_nopt()

# %%
pyrace.plot_bar_parameters(opt.get_best(), simplex.get_best(), labels=['diffev', 'simplex'])

# %% [markdown]
# ### let's see how well we have recovered the parameters

# %%
# and look at the best individual
bestde=opt.get_best()
bestsimp=simplex.get_best()
display(bestde)
display(bestsimp)

pl.figure(figsize=(10,5))
pyrace.plot_bar_parameters(bestde, bestsimp, truepar, labels=['bestde', 'bestsimp', 'true'])
# Out:
# Testparspec(ter=0.57,A=0.23,B=3.37,V=-3.11,v=5.00)
# Testparspec(ter=0.66,A=0.00,B=2.96,V=-3.75,v=5.00)
